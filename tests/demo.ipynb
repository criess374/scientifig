# %%
import numpy as np
import scientifig
import matplotlib.pyplot as plt

# %%
scientifig.use_style("paper", width=1, background="transparent")
fig, ax = scientifig.create_figure(figsize=(8, 5))

x = np.linspace(0, 10, 100)
y = np.sin(x)

ax.plot(x, y, label="Sine Wave")
ax.set_title("Sine Wave Plot")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")

ax.annotate(
    "Annotation",
    xy=(5, 0),
    xytext=(6, 0.5),
    arrowprops=dict(shrink=0.05),
)
# add legend at top right
plt.legend(loc="lower right")
scientifig.savefig(fig, "testplots/sine_wave_plot.png")
plt.show()

# %%
import cartopy.crs as ccrs
import cartopy.feature as cfeature

scientifig.use_style("paper", width=1.0, background="black")

fig, ax = scientifig.create_figure(
    figsize=(5, 5), subplot_kw={"projection": ccrs.PlateCarree()}
)

ax.add_feature(cfeature.LAND, facecolor="lightgray")
ax.add_feature(cfeature.OCEAN, facecolor="lightblue")
ax.add_feature(cfeature.COASTLINE)
ax.add_feature(cfeature.BORDERS, linewidth=0.4, linestyle="--")
ax.set_extent([-180, 180, -90, 90], crs=ccrs.PlateCarree())
gl = ax.gridlines(draw_labels=True, color="gray", linestyle="--")
gl.top_labels = False
gl.right_labels = False
ax.set_title("World Map", y=1.05)


# scientifig.savefig(fig, "testplots/world_map")
plt.show()

# %%
from pathlib import Path

scientifig.THEMES["mytheme"] = {
    "mplstyle": Path(
        "C:/Users/riec/Documents/scientifig/scientifig/mplstyle/paper_pride.mplstyle"
    ),
    "canvas_width_in": 6.0,
}
scientifig.use_style("mytheme", width=1.0)


fig, ax = scientifig.create_figure(figsize=(5, 8))

x = np.linspace(0, 10, 100)

for i in range(6):
    y = np.sin(x * (1 + 0.15 * i) + i) + 0.3 * i
    ax.plot(x, y, label=f"Sine {i + 1}")

ax.set_title("Sine Wave Pride Plot")
ax.set_xlabel("X-axis")
ax.set_ylabel("Y-axis")
plt.legend()


scientifig.savefig(fig, "testplots/sine_wave_plot.png")
plt.show()
